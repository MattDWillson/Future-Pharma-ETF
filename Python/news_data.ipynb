# %%
import requests
import pandas as pd
import regex as re
import os
from dotenv import load_dotenv
import matplotlib.pyplot as plt

from nltk.corpus import stopwords, reuters
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
from wordcloud import WordCloud

load_dotenv()
# Out:
# True

# %%
def clean_tokenize(raw_text):
    lemmatizer = WordNetLemmatizer()
    cleanr = re.compile('\.+|<.*?>|&([a-z0-9]+|#[0-9]{1,6}|#x[0-9a-f]{1,6});')
    cleantext = re.sub(cleanr, '', raw_text).replace('\r', ' ').replace('\t', ' ').replace('\n', ' ').strip()
    new_content = ' '.join(cleantext.split())
    sw = set(stopwords.words('english'))
    regex = re.compile("[^a-zA-Z ]")
    re_clean = regex.sub('', new_content)
    words = word_tokenize(re_clean)
    lem = [lemmatizer.lemmatize(word) for word in words]
    output = [word.lower() for word in lem if word.lower() not in sw]
    return ' '.join(output)

# %%
def get_news(tickers, range_of_dates):
    news_df = pd.DataFrame()
    ticker_string = ','.join(tickers)
    for date in range_of_dates:
        url = f'https://api.benzinga.com/api/v2/news?token=6b65009cb3594ca380ef509da6e1deee&date={str(date.date())}&tickers={ticker_string}&displayOutput=full'
        data = requests.get(url, headers={'accept': 'application/json'})
        news_df = news_df.append(data.json())
    news_df = news_df.drop(['id', 'author', 'updated', 'teaser', 'url', 'image', 'channels', 'tags'], axis=1)
    news_df['created'] = pd.to_datetime(pd.to_datetime(news_df['created']).dt.date).dt.normalize()
    news_df = news_df.rename(columns={'created': 'date'})
    return news_df

# %%
news_df = get_news(['AZN', 'JNJ', 'PFE', 'MRNA'], pd.date_range('2020-09-01', '2021-09-15'))
news_df['word_tokens'] = news_df['body'].apply(clean_tokenize)
news_df['word_tokens'] += news_df['title'].apply(clean_tokenize)

# %%
def assign_ticker(x):
    if 'AZN' in  [value for elem in x for value in elem.values()]:
        return 'AZN'
    if 'MRNA' in  [value for elem in x for value in elem.values()]:
        return 'MRNA'
    if 'JNJ' in  [value for elem in x for value in elem.values()]:
        return 'JNJ'
    if 'PFE' in  [value for elem in x for value in elem.values()]:
        return 'PFE'

news_df['symbol'] = news_df['stocks'].apply(assign_ticker)

# %%
news_df
# Out:
#          date                                              title  \
# 0  2020-09-16  AstraZeneca Trial Participant Adverse Events L...
# 1  2020-09-17  Sinovac Plans To Expand COVID-19 Vaccine Trial...
# 2  2020-09-17           5 Stocks To Watch For September 17, 2020
# 3  2020-09-17  BioNTech Buys German Biotech Production Site f...
# 4  2020-09-17  AstraZeneca Acquires Oral PCSK9 Inhibitor Prog...
# ..        ...                                                ...
# 10 2021-09-15  FDA Declines To Take Stance On Pfizer's COVID-...
# 11 2021-09-15  Pfizer Builds Case For COVID-19 Booster As Pro...
# 12 2021-09-15  Moderna Highlights New Clinical Data On COVID-...
# 13 2021-09-15  UPDATE: Moderna Says 'mRNA-1273 remains highly...
# 14 2021-09-15  UPDATE: Moderna Says 'New analysis of open-lab...
#
#                                                  body  \
# 0   <p><strong>AstraZeneca Plc&rsquo;s </strong>(N...
# 1   <p><strong>Sinovac Biotech</strong> has plans ...
# 2   <p>Some of the stocks that may grab investor f...
# 3   BioNTech SE (NASDAQ:<a class="ticker" href="/s...
# 4   AstraZeneca (NYSE:<a class="ticker" href="/sto...
# ..                                                ...
# 10                                    <p>-Reuters</p>
# 11  <ul>\r\n\t<li><strong>Pfizer Inc</strong>&nbsp...
# 12  <h1>Moderna Highlights New Clinical Data on it...
# 13
# 14
#
#                                                stocks  \
# 0   [{'name': 'AZN'}, {'name': 'MRNA'}, {'name': '...
# 1   [{'name': 'AZN'}, {'name': 'BNTX'}, {'name': '...
# 2   [{'name': 'APOG'}, {'name': 'CHWY'}, {'name': ...
# 3   [{'name': 'BNTX'}, {'name': 'NVS'}, {'name': '...
# 4                                   [{'name': 'AZN'}]
# ..                                                ...
# 10                [{'name': 'BNTX'}, {'name': 'PFE'}]
# 11                [{'name': 'BNTX'}, {'name': 'PFE'}]
# 12                                 [{'name': 'MRNA'}]
# 13                                 [{'name': 'MRNA'}]
# 14                                 [{'name': 'MRNA'}]
#
#                                           word_tokens symbol
# 0   astrazeneca plcs nyseazn vaccine didnt likely ...    AZN
# 1   sinovac biotech ha plan expand clinical trial ...    AZN
# 2   stock may grab investor focus today wall stree...   MRNA
# 3   biontech se nasdaqbntx today announced signing...    PFE
# 4   astrazeneca nyseazn ha entered agreement dogma...    AZN
# ..                                                ...    ...
# 10  reutersfda declines take stance pfizers covid ...    PFE
# 11  pfizer incnysepfe said us regulator approve bo...    PFE
# 12  moderna highlights new clinical data covid vac...   MRNA
# 13  update moderna says mrna remains highly effect...   MRNA
# 14  update moderna says new analysis openlabel por...   MRNA
#
# [3670 rows x 6 columns]

# %%
big_string = ' '.join(news_df['word_tokens'].values)
wc = WordCloud().generate(big_string)
plt.imshow(wc)

# %%
from collections import Counter
from nltk import ngrams

# %%
news_bigrams = ngrams([word for value in news_df['word_tokens'].values for word in value.split()], n=2)
list(news_bigrams)
# Out:
# [('astrazeneca', 'plcs'),
#  ('plcs', 'nyseazn'),
#  ('nyseazn', 'vaccine'),
#  ('vaccine', 'didnt'),
#  ('didnt', 'likely'),
#  ('likely', 'cause'),
#  ('cause', 'adverse'),
#  ('adverse', 'event'),
#  ('event', 'suspended'),
#  ('suspended', 'latestage'),
#  ('latestage', 'human'),
#  ('human', 'trial'),
#  ('trial', 'drug'),
#  ('drug', 'according'),
#  ('according', 'oxford'),
#  ('oxford', 'university'),
#  ('university', 'happened'),
#  ('happened', 'volunteers'),
#  ('volunteers', 'british'),
#  ('british', 'drugmakers'),
#  ('drugmakers', 'chadox'),
#  ('chadox', 'ncov'),
#  ('ncov', 'vaccine'),
#  ('vaccine', 'trial'),
#  ('trial', 'developed'),
#  ('developed', 'unexplained'),
#  ('unexplained', 'neurological'),
#  ('neurological', 'symptom'),
#  ('symptom', 'including'),
#  ('including', 'changed'),
#  ('changed', 'sensation'),
#  ('sensation', 'weakness'),
#  ('weakness', 'limb'),
#  ('limb', 'according'),
#  ('according', 'participant'),
#  ('participant', 'information'),
#  ('information', 'document'),
#  ('document', 'published'),
#  ('published', 'oxford'),
#  ('oxford', 'codeveloping'),
#  ('codeveloping', 'vaccine'),
#  ('vaccine', 'astrazeneca'),
#  ('astrazeneca', 'independent'),
#  ('independent', 'review'),
#  ('review', 'illness'),
#  ('illness', 'either'),
#  ('either', 'considered'),
#  ('considered', 'unlikely'),
#  ('unlikely', 'associated'),
#  ('associated', 'vaccine'),
#  ('vaccine', 'wa'),
#  ('wa', 'insufficient'),
#  ('insufficient', 'evidence'),
#  ('evidence', 'say'),
#  ('say', 'certain'),
#  ('certain', 'illness'),
#  ('illness', 'related'),
#  ('related', 'vaccine'),
#  ('vaccine', 'oxford'),
#  ('oxford', 'said'),
#  ('said', 'first'),
#  ('first', 'reported'),
#  ('reported', 'reuters'),
#  ('reuters', 'independent'),
#  ('independent', 'reviewer'),
#  ('reviewer', 'recommended'),
#  ('recommended', 'vaccination'),
#  ('vaccination', 'continue'),
#  ('continue', 'reviewing'),
#  ('reviewing', 'case'),
#  ('case', 'according'),
#  ('according', 'document'),
#  ('document', 'matters'),
#  ('matters', 'astrazeneca'),
#  ('astrazeneca', 'ha'),
#  ('ha', 'resumed'),
#  ('resumed', 'trial'),
#  ('trial', 'vaccine'),
#  ('vaccine', 'united'),
#  ('united', 'kingdom'),
#  ('kingdom', 'india'),
#  ('india', 'south'),
#  ('south', 'africa'),
#  ('africa', 'brazil'),
#  ('brazil', 'trials'),
#  ('trials', 'havent'),
#  ('havent', 'yet'),
#  ('yet', 'resumed'),
#  ('resumed', 'united'),
#  ('united', 'states'),
#  ('states', 'food'),
#  ('food', 'drug'),
#  ('drug', 'administration'),
#  ('administration', 'commissioner'),
#  ('commissioner', 'stephen'),
#  ('stephen', 'hahn'),
#  ('hahn', 'said'),
#  ('said', 'agency'),
#  ('agency', 'going'),
#  ('going', 'significant'),
#  ('significant', 'work'),
#  ('work', 'company'),
#  ('company', 'figure'),
#  ('figure', 'significant'),
#  ('significant', 'safety'),
#  ('safety', 'issue'),
#  ('issue', 'moderna'),
#  ('moderna', 'inc'),
#  ('inc', 'nysemrna'),
#  ('nysemrna', 'pfizer'),
#  ('pfizer', 'inc'),
#  ('inc', 'nysepfe'),
#  ('nysepfe', 'likely'),
#  ('likely', 'frontrunners'),
#  ('frontrunners', 'race'),
#  ('race', 'covid'),
#  ('covid', 'vaccine'),
#  ('vaccine', 'microsoft'),
#  ('microsoft', 'corporation'),
#  ('corporation', 'nasdaqmsft'),
#  ('nasdaqmsft', 'cofounder'),
#  ('cofounder', 'bill'),
#  ('bill', 'gates'),
#  ('gates', 'claimed'),
#  ('claimed', 'pfizers'),
#  ('pfizers', 'vaccine'),
#  ('vaccine', 'may'),
#  ('may', 'get'),
#  ('get', 'emergency'),
#  ('emergency', 'use'),
#  ('use', 'license'),
#  ('license', 'end'),
#  ('end', 'october'),
#  ('october', 'according'),
#  ('according', 'cnbc'),
#  ('cnbc', 'price'),
#  ('price', 'action'),
#  ('action', 'astrazeneca'),
#  ('astrazeneca', 'share'),
#  ('share', 'closed'),
#  ('closed', 'almost'),
#  ('almost', 'lower'),
#  ('lower', 'wednesday'),
#  ('wednesday', 'gained'),
#  ('gained', 'afterhours'),
#  ('afterhours', 'sessionastrazeneca'),
#  ('sessionastrazeneca', 'trial'),
#  ('trial', 'participant'),
#  ('participant', 'adverse'),
#  ('adverse', 'events'),
#  ('events', 'likely'),
#  ('likely', 'unrelated'),
#  ('unrelated', 'covid'),
#  ('covid', 'vaccine'),
#  ('vaccine', 'oxford'),
#  ('oxford', 'sinovac'),
#  ('sinovac', 'biotech'),
#  ('biotech', 'ha'),
#  ('ha', 'plan'),
#  ('plan', 'expand'),
#  ('expand', 'clinical'),
#  ('clinical', 'trial'),
#  ('trial', 'covid'),
#  ('covid', 'vaccine'),
#  ('vaccine', 'trial'),
#  ('trial', 'child'),
#  ('child', 'adolescent'),
#  ('adolescent', 'later'),
#  ('later', 'month'),
#  ('month', 'happened'),
#  ('happened', 'chinese'),
#  ('chinese', 'vaccine'),
#  ('vaccine', 'maker'),
#  ('maker', 'hope'),
#  ('hope', 'carry'),
#  ('carry', 'study'),
#  ('study', 'healthy'),
#  ('healthy', 'participant'),
#  ('participant', 'ranging'),
#  ('ranging', 'age'),
#  ('age', 'three'),
#  ('three', 'according'),
#  ('according', 'information'),
#  ('information', 'company'),
#  ('company', 'filed'),
#  ('filed', 'national'),
#  ('national', 'library'),
#  ('library', 'medicine'),
#  ('medicine', 'combined'),
#  ('combined', 'phase'),
#  ('phase', 'phase'),
#  ('phase', 'trial'),
#  ('trial', 'take'),
#  ('take', 'place'),
#  ('place', 'chinas'),
#  ('chinas', 'hebei'),
#  ('hebei', 'province'),
#  ('province', 'commence'),
#  ('commence', 'sept'),
#  ('sept', 'company'),
#  ('company', 'said'),
#  ('said', 'asfirst'),
#  ('asfirst', 'noticed'),
#  ('noticed', 'reuters'),
#  ('reuters', 'drugmaker'),
#  ('drugmaker', 'said'),
#  ('said', 'volunteer'),
#  ('volunteer', 'would'),
#  ('would', 'given'),
#  ('given', 'two'),
#  ('two', 'dos'),
#  ('dos', 'drugmakers'),
#  ('drugmakers', 'coronavac'),
#  ('coronavac', 'vaccineor'),
#  ('vaccineor', 'alternatively'),
#  ('alternatively', 'placebo'),
#  ('placebo', 'trial'),
#  ('trial', 'ha'),
#  ('ha', 'already'),
#  ('already', 'approved'),
#  ('approved', 'chinas'),
#  ('chinas', 'regulator'),
#  ('regulator', 'sinovac'),
#  ('sinovac', 'spokesperson'),
#  ('spokesperson', 'told'),
#  ('told', 'reuters'),
#  ('reuters', 'matters'),
#  ('matters', 'vaccine'),
#  ('vaccine', 'work'),
#  ('work', 'entire'),
#  ('entire', 'population'),
#  ('population', 'important'),
#  ('important', 'covid'),
#  ('covid', 'spread'),
#  ('spread', 'adult'),
#  ('adult', 'school'),
#  ('school', 'kindergarten'),
#  ('kindergarten', 'reuters'),
#  ('reuters', 'noted'),
#  ('noted', 'pfizer'),
#  ('pfizer', 'inc'),
#  ('inc', 'nysepfe'),
#  ('nysepfe', 'german'),
#  ('german', 'partner'),
#  ('partner', 'biontech'),
#  ('biontech', 'se'),
#  ('se', 'nasdaqbntx'),
#  ('nasdaqbntx', 'seeking'),
#  ('seeking', 'approval'),
#  ('approval', 'united'),
#  ('united', 'states'),
#  ('states', 'food'),
#  ('food', 'drug'),
#  ('drug', 'administration'),
#  ('administration', 'expand'),
#  ('expand', 'drug'),
#  ('drug', 'trial'),
#  ('trial', 'including'),
#  ('including', 'adolescent'),
#  ('adolescent', 'young'),
#  ('young', 'year'),
#  ('year', 'old'),
#  ('old', 'pfizer'),
#  ('pfizer', 'moderna'),
#  ('moderna', 'inc'),
#  ('inc', 'nasdaqmrna'),
#  ('nasdaqmrna', 'vaccine'),
#  ('vaccine', 'likely'),
#  ('likely', 'distributed'),
#  ('distributed', 'health'),
#  ('health', 'care'),
#  ('care', 'worker'),
#  ('worker', 'highrisk'),
#  ('highrisk', 'group'),
#  ('group', 'late'),
#  ('late', 'october'),
#  ('october', 'early'),
#  ('early', 'november'),
#  ('november', 'according'),
#  ('according', 'new'),
#  ('new', 'york'),
#  ('york', 'times'),
#  ('times', 'oxford'),
#  ('oxford', 'university'),
#  ('university', 'said'),
#  ('said', 'partner'),
#  ('partner', 'astrazeneca'),
#  ('astrazeneca', 'plcs'),
#  ('plcs', 'nyseazn'),
#  ('nyseazn', 'covid'),
#  ('covid', 'vaccine'),
#  ('vaccine', 'wasntthe'),
#  ('wasntthe', 'likely'),
#  ('likely', 'cause'),
#  ('cause', 'neurological'),
#  ('neurological', 'symptom'),
#  ('symptom', 'weakness'),
#  ('weakness', 'limb'),
#  ('limb', 'latestage'),
#  ('latestage', 'trial'),
#  ('trial', 'participant'),
#  ('participant', 'british'),
#  ('british', 'drugmaker'),
#  ('drugmaker', 'ha'),
#  ('ha', 'resumed'),
#  ('resumed', 'latestage'),
#  ('latestage', 'trial'),
#  ('trial', 'united'),
#  ('united', 'kingdom'),
#  ('kingdom', 'india'),
#  ('india', 'brazil'),
#  ('brazil', 'south'),
#  ('south', 'africa'),
#  ('africa', 'halted'),
#  ('halted', 'due'),
#  ('due', 'reported'),
#  ('reported', 'adverse'),
#  ('adverse', 'event'),
#  ('event', 'earliersinovac'),
#  ('earliersinovac', 'plans'),
#  ('plans', 'expand'),
#  ('expand', 'covid'),
#  ('covid', 'vaccine'),
#  ('vaccine', 'trials'),
#  ('trials', 'children'),
#  ('children', 'adolescents'),
#  ('adolescents', 'stock'),
#  ('stock', 'may'),
#  ('may', 'grab'),
#  ('grab', 'investor'),
#  ('investor', 'focus'),
#  ('focus', 'today'),
#  ('today', 'wall'),
#  ('wall', 'street'),
#  ('street', 'expects'),
#  ('expects', 'apogee'),
#  ('apogee', 'enterprises'),
#  ('enterprises', 'inc'),
#  ('inc', 'nasdaqapog'),
#  ('nasdaqapog', 'report'),
#  ('report', 'quarterly'),
#  ('quarterly', 'earnings'),
#  ('earnings', 'per'),
#  ('per', 'share'),
#  ('share', 'revenue'),
#  ('revenue', 'million'),
#  ('million', 'opening'),
#  ('opening', 'bell'),
#  ('bell', 'apogee'),
#  ('apogee', 'share'),
#  ('share', 'slipped'),
#  ('slipped', 'afterhours'),
#  ('afterhours', 'trading'),
#  ('trading', 'herman'),
#  ('herman', 'miller'),
#  ('miller', 'inc'),
#  ('inc', 'nasdaqmlhr'),
#  ('nasdaqmlhr', 'reported'),
#  ('reported', 'strong'),
#  ('strong', 'rise'),
#  ('rise', 'earnings'),
#  ('earnings', 'fiscal'),
#  ('fiscal', 'first'),
#  ('first', 'quarter'),
#  ('quarter', 'company'),
#  ('company', 'sale'),
#  ('sale', 'also'),
#  ('also', 'exceeded'),
#  ('exceeded', 'analyst'),
#  ('analyst', 'estimate'),
#  ('estimate', 'herman'),
#  ('herman', 'miller'),
#  ('miller', 'share'),
#  ('share', 'jumped'),
#  ('jumped', 'afterhours'),
#  ('afterhours', 'trading'),
#  ('trading', 'session'),
#  ('session', 'analysts'),
#  ('analysts', 'expect'),
#  ('expect', 'cantel'),
#  ('cantel', 'medical'),
#  ('medical', 'corp'),
#  ('corp', 'nysecmd'),
#  ('nysecmd', 'report'),
#  ('report', 'quarterly'),
#  ('quarterly', 'loss'),
#  ('loss', 'per'),
#  ('per', 'share'),
#  ('share', 'revenue'),
#  ('revenue', 'million'),
#  ('million', 'opening'),
#  ('opening', 'bell'),
#  ('bell', 'cantel'),
#  ('cantel', 'medical'),
#  ('medical', 'share'),
#  ('share', 'gained'),
#  ('gained', 'afterhours'),
#  ('afterhours', 'trading'),
#  ('trading', 'find'),
#  ('find', 'whats'),
#  ('whats', 'going'),
#  ('going', 'today'),
#  ('today', 'market'),
#  ('market', 'bring'),
#  ('bring', 'question'),
#  ('question', 'benzingas'),
#  ('benzingas', 'premarket'),
#  ('premarket', 'prep'),
#  ('prep', 'choosing'),
#  ('choosing', 'best'),
#  ('best', 'broker'),
#  ('broker', 'important'),
#  ('important', 'part'),
#  ('part', 'successful'),
#  ('successful', 'trader'),
#  ('trader', 'investor'),
#  ('investor', 'moderna'),
#  ('moderna', 'inc'),
#  ('inc', 'nasdaqmrna'),
#  ('nasdaqmrna', 'reported'),
#  ('reported', 'collaboration'),
#  ('collaboration', 'chiesi'),
#  ('chiesi', 'group'),
#  ('group', 'discover'),
#  ('discover', 'develop'),
#  ('develop', 'mrna'),
#  ('mrna', 'pulmonary'),
#  ('pulmonary', 'arterial'),
#  ('arterial', 'hypertension'),
#  ('hypertension', 'company'),
#  ('company', 'also'),
#  ('also', 'announced'),
#  ('announced', 'collaboration'),
#  ('collaboration', 'vertex'),
#  ('vertex', 'treat'),
#  ('treat', 'cystic'),
#  ('cystic', 'fibrosis'),
#  ('fibrosis', 'using'),
#  ('using', 'gene'),
#  ('gene', 'editing'),
#  ('editing', 'moderna'),
#  ('moderna', 'share'),
#  ('share', 'gained'),
#  ('gained', 'afterhours'),
#  ('afterhours', 'trading'),
#  ('trading', 'session'),
#  ('session', 'chewy'),
#  ('chewy', 'inc'),
#  ('inc', 'nysechwy'),
#  ('nysechwy', 'reported'),
#  ('reported', 'public'),
#  ('public', 'offering'),
#  ('offering', 'million'),
#  ('million', 'share'),
#  ('share', 'class'),
#  ('class', 'common'),
#  ('common', 'stock'),
#  ('stock', 'chewy'),
#  ('chewy', 'share'),
#  ('share', 'fell'),
#  ('fell', 'afterhours'),
#  ('afterhours', 'tradingstocks'),
#  ('tradingstocks', 'watch'),
#  ('watch', 'september'),
#  ('september', 'biontech'),
#  ('biontech', 'se'),
#  ('se', 'nasdaqbntx'),
#  ('nasdaqbntx', 'today'),
#  ('today', 'announced'),
#  ('announced', 'signing'),
#  ('signing', 'share'),
#  ('share', 'purchase'),
#  ('purchase', 'agreement'),
#  ('agreement', 'novartis'),
#  ('novartis', 'ag'),
#  ('ag', 'basel'),
#  ('basel', 'switzerland'),
#  ('switzerland', 'nysenvs'),
#  ('nysenvs', 'acquire'),
#  ('acquire', 'gmp'),
#  ('gmp', 'certified'),
#  ('certified', 'manufacturing'),
#  ('manufacturing', 'facility'),
#  ('facility', 'marburg'),
#  ('marburg', 'germany'),
#  ('germany', 'manufacturing'),
#  ('manufacturing', 'site'),
#  ('site', 'expand'),
#  ('expand', 'biontechs'),
#  ('biontechs', 'covid'),
#  ('covid', 'vaccine'),
#  ('vaccine', 'production'),
#  ('production', 'capacity'),
#  ('capacity', 'million'),
#  ('million', 'dos'),
#  ('dos', 'per'),
#  ('per', 'year'),
#  ('year', 'million'),
#  ('million', 'dos'),
#  ('dos', 'per'),
#  ('per', 'month'),
#  ('month', 'fully'),
#  ('fully', 'operational'),
#  ('operational', 'transaction'),
#  ('transaction', 'expected'),
#  ('expected', 'close'),
#  ('close', 'fourth'),
#  ('fourth', 'quarter'),
#  ('quarter', 'company'),
#  ('company', 'plan'),
#  ('plan', 'able'),
#  ('able', 'produce'),
#  ('produce', 'million'),
#  ('million', 'dos'),
#  ('dos', 'bntb'),
#  ('bntb', 'first'),
#  ('first', 'half'),
#  ('half', 'thanks'),
#  ('thanks', 'established'),
#  ('established', 'team'),
#  ('team', 'wellestablished'),
#  ('wellestablished', 'drug'),
#  ('drug', 'substance'),
#  ('substance', 'drug'),
#  ('drug', 'product'),
#  ('product', 'manufacturing'),
#  ('manufacturing', 'capability'),
#  ('capability', 'site'),
#  ('site', 'marburg'),
#  ('marburg', 'production'),
#  ('production', 'site'),
#  ('site', 'stateoftheart'),
#  ('stateoftheart', 'multiplatform'),
#  ('multiplatform', 'gmp'),
#  ('gmp', 'certified'),
#  ('certified', 'manufacturing'),
#  ('manufacturing', 'facility'),
#  ('facility', 'currently'),
#  ('currently', 'employ'),
#  ('employ', 'approximately'),
#  ('approximately', 'people'),
#  ('people', 'fully'),
#  ('fully', 'equipped'),
#  ('equipped', 'production'),
#  ('production', 'recombinant'),
#  ('recombinant', 'protein'),
#  ('protein', 'well'),
#  ('well', 'cell'),
#  ('cell', 'gene'),
#  ('gene', 'therapy'),
#  ('therapy', 'hold'),
#  ('hold', 'cell'),
#  ('cell', 'culture'),
#  ('culture', 'lab'),
#  ('lab', 'viral'),
#  ('viral', 'vector'),
#  ('vector', 'production'),
#  ('production', 'capability'),
#  ('capability', 'potential'),
#  ('potential', 'longterm'),
#  ('longterm', 'growth'),
#  ('growth', 'expansion'),
#  ('expansion', 'novartis'),
#  ('novartis', 'ha'),
#  ('ha', 'significantly'),
#  ('significantly', 'invested'),
#  ('invested', 'site'),
#  ('site', 'past'),
#  ('past', 'five'),
#  ('five', 'year'),
#  ('year', 'located'),
#  ('located', 'life'),
#  ('life', 'science'),
#  ('science', 'industry'),
#  ('industry', 'park'),
#  ('park', 'home'),
#  ('home', 'company'),
#  ('company', 'employee'),
#  ('employee', 'total'),
#  ('total', 'also'),
#  ('also', 'provides'),
#  ('provides', 'excellent'),
#  ('excellent', 'infrastructure'),
#  ('infrastructure', 'company'),
#  ('company', 'industrial'),
#  ('industrial', 'park'),
#  ('park', 'located'),
#  ('located', 'within'),
#  ('within', 'one'),
#  ('one', 'hour'),
#  ('hour', 'frankfurt'),
#  ('frankfurt', 'airport'),
#  ('airport', 'within'),
#  ('within', 'minute'),
#  ('minute', 'biontechs'),
#  ('biontechs', 'headquarters'),
#  ('headquarters', 'mainz'),
#  ('mainz', 'germany'),
#  ('germany', 'acquisition'),
#  ('acquisition', 'reflects'),
#  ('reflects', 'biontechs'),
#  ('biontechs', 'commitment'),
#  ('commitment', 'significantly'),
#  ('significantly', 'expanding'),
#  ('expanding', 'manufacturing'),
#  ('manufacturing', 'capacity'),
#  ('capacity', 'order'),
#  ('order', 'supply'),
#  ('supply', 'potential'),
#  ('potential', 'vaccine'),
#  ('vaccine', 'worldwide'),
#  ('worldwide', 'upon'),
#  ('upon', 'authorization'),
#  ('authorization', 'approval'),
#  ('approval', 'working'),
#  ('working', 'closely'),
#  ('closely', 'novartis'),
#  ('novartis', 'prepare'),
#  ('prepare', 'smooth'),
#  ('smooth', 'transition'),
#  ('transition', 'look'),
#  ('look', 'forward'),
#  ('forward', 'welcoming'),
#  ('welcoming', 'new'),
#  ('new', 'member'),
#  ('member', 'team'),
#  ('team', 'tapping'),
#  ('tapping', 'impressive'),
#  ('impressive', 'skill'),
#  ('skill', 'expertise'),
#  ('expertise', 'strategic'),
#  ('strategic', 'standpoint'),
#  ('standpoint', 'new'),
#  ('new', 'site'),
#  ('site', 'bolster'),
#  ('bolster', 'vertically'),
#  ('vertically', 'integrated'),
#  ('integrated', 'business'),
#  ('business', 'model'),
#  ('model', 'inhouse'),
#  ('inhouse', 'manufacturing'),
#  ('manufacturing', 'capability'),
#  ('capability', 'mrna'),
#  ('mrna', 'manufacturing'),
#  ('manufacturing', 'well'),
#  ('well', 'vaccine'),
#  ('vaccine', 'formulation'),
#  ('formulation', 'said'),
#  ('said', 'dr'),
#  ('dr', 'sierk'),
#  ('sierk', 'poetting'),
#  ('poetting', 'chief'),
#  ('chief', 'financial'),
#  ('financial', 'officer'),
#  ('officer', 'chief'),
#  ('chief', 'operating'),
#  ('operating', 'officer'),
#  ('officer', 'biontech'),
#  ('biontech', 'acquisition'),
#  ('acquisition', 'accelerate'),
#  ('accelerate', 'biontechs'),
#  ('biontechs', 'effort'),
#  ('effort', 'scaleup'),
#  ('scaleup', 'commercial'),
#  ('commercial', 'manufacturing'),
#  ('manufacturing', 'capacity'),
#  ('capacity', 'produce'),
#  ('produce', 'mrna'),
#  ('mrna', 'covid'),
#  ('covid', 'vaccine'),
#  ('vaccine', 'candidate'),
#  ('candidate', 'bnt'),
#  ('bnt', 'bnt'),
#  ('bnt', 'program'),
#  ('program', 'includes'),
#  ('includes', 'five'),
#  ('five', 'mrna'),
#  ('mrna', 'vaccine'),
#  ('vaccine', 'candidate'),
#  ('candidate', 'currently'),
#  ('currently', 'clinical'),
#  ('clinical', 'testing'),
#  ('testing', 'united'),
#  ('united', 'states'),
#  ('states', 'europe'),
#  ('europe', 'south'),
#  ('south', 'america'),
#  ('america', 'china'),
#  ('china', 'biontech'),
#  ('biontech', 'pfizer'),
#  ('pfizer', 'evaluating'),
#  ('evaluating', 'lead'),
#  ('lead', 'candidate'),
#  ('candidate', 'bntb'),
#  ('bntb', 'global'),
#  ('global', 'phase'),
#  ('phase', 'trial'),
#  ('trial', 'facility'),
#  ('facility', 'expected'),
#  ('expected', 'operate'),
#  ('operate', 'one'),
#  ('one', 'largest'),
#  ('largest', 'mrna'),
#  ('mrna', 'manufacturing'),
#  ('manufacturing', 'site'),
#  ('site', 'europe'),
#  ('europe', 'alongside'),
#  ('alongside', 'two'),
#  ('two', 'biontechs'),
#  ('biontechs', 'existing'),
#  ('existing', 'gmp'),
#  ('gmp', 'facility'),
#  ('facility', 'currently'),
#  ('currently', 'produce'),
#  ('produce', 'covid'),
#  ('covid', 'vaccine'),
#  ('vaccine', 'candidate'),
#  ('candidate', 'clinical'),
#  ('clinical', 'trial'),
#  ('trial', 'addition'),
#  ('addition', 'least'),
#  ('least', 'four'),
#  ('four', 'pfizer'),
#  ('pfizer', 'production'),
#  ('production', 'site'),
#  ('site', 'united'),
#  ('united', 'states'),
#  ('states', 'europe'),
#  ('europe', 'marburg'),
#  ('marburg', 'facility'),
#  ('facility', 'expected'),
#  ('expected', 'start'),
#  ('start', 'production'),
#  ('production', 'mrna'),
#  ('mrna', 'lnp'),
#  ('lnp', 'formulation'),
#  ('formulation', 'covid'),
#  ('covid', 'vaccine'),
#  ('vaccine', 'first'),
#  ('first', 'half'),
#  ('half', 'pending'),
#  ('pending', 'regulatory'),
#  ('regulatory', 'authorization'),
#  ('authorization', 'approval'),
#  ('approval', 'biontech'),
#  ('biontech', 'plan'),
#  ('plan', 'manufacture'),
#  ('manufacture', 'additional'),
#  ('additional', 'therapeutic'),
#  ('therapeutic', 'vaccine'),
#  ('vaccine', 'drug'),
#  ('drug', 'candidate'),
#  ('candidate', 'plant'),
#  ('plant', 'mrna'),
#  ('mrna', 'vaccine'),
#  ('vaccine', 'antibody'),
#  ('antibody', 'cell'),
#  ('cell', 'gene'),
#  ('gene', 'therapy'),
#  ('therapy', 'product'),
#  ('product', 'candidate'),
#  ('candidate', 'support'),
#  ('support', 'development'),
#  ('development', 'diversified'),
#  ('diversified', 'cancer'),
#  ('cancer', 'infectious'),
#  ('infectious', 'disease'),
#  ('disease', 'product'),
#  ('product', 'pipeline'),
#  ('pipeline', 'addition'),
#  ('addition', 'biontech'),
#  ('biontech', 'intends'),
#  ('intends', 'use'),
#  ('use', 'marburg'),
#  ('marburg', 'facility'),
#  ('facility', 'contribute'),
#  ('contribute', 'production'),
#  ('production', 'covid'),
#  ('covid', 'vaccine'),
#  ('vaccine', 'global'),
#  ('global', 'supply'),
#  ('supply', 'including'),
#  ('including', 'china'),
#  ('china', 'partnered'),
#  ('partnered', 'fosun'),
#  ('fosun', 'pharma'),
#  ('pharma', 'subject'),
#  ('subject', 'regulatory'),
#  ('regulatory', 'authorization'),
#  ('authorization', 'approval'),
#  ('approval', 'marburg'),
#  ('marburg', 'facility'),
#  ('facility', 'ha'),
#  ('ha', 'year'),
#  ('year', 'long'),
#  ('long', 'tradition'),
#  ('tradition', 'innovation'),
#  ('innovation', 'manufacturing'),
#  ('manufacturing', 'site'),
#  ('site', 'named'),
#  ('named', 'behringwerke'),
#  ('behringwerke', 'wa'),
#  ('wa', 'established'),
#  ('established', 'emil'),
#  ('emil', 'von'),
#  ('von', 'behring'),
#  ('behring', 'developed'),
#  ('developed', 'antitoxin'),
#  ('antitoxin', 'diphtheria'),
#  ('diphtheria', 'tetanus'),
#  ('tetanus', 'used'),
#  ('used', 'award'),
#  ('award', 'money'),
#  ('money', 'received'),
#  ('received', 'nobel'),
#  ('nobel', 'prize'),
#  ('prize', 'medicine'),
#  ('medicine', 'finance'),
#  ('finance', 'manufacturing'),
#  ('manufacturing', 'site'),
#  ('site', 'since'),
#  ('since', 'founding'),
#  ('founding', 'behringwerke'),
#  ('behringwerke', 'ha'),
#  ('ha', 'forefront'),
#  ('forefront', 'pharmaceutical'),
#  ('pharmaceutical', 'biologic'),
#  ('biologic', 'innovation'),
#  ('innovation', 'including'),
#  ('including', 'production'),
#  ('production', 'vaccine'),
#  ('vaccine', 'resulting'),
#  ('resulting', 'highly'),
#  ('highly', 'established'),
#  ('established', 'infrastructure'),
#  ('infrastructure', 'biontech'),
#  ('biontech', 'novartis'),
#  ('novartis', 'anticipate'),
#  ('anticipate', 'completing'),
#  ('completing', 'transaction'),
#  ('transaction', 'fourth'),
#  ('fourth', 'quarter'),
#  ('quarter', 'subject'),
#  ('subject', 'regulatory'),
#  ('regulatory', 'approval'),
#  ('approval', 'satisfaction'),
#  ('satisfaction', 'certain'),
#  ('certain', 'customary'),
#  ('customary', 'closing'),
#  ('closing', 'conditionbiontech'),
#  ('conditionbiontech', 'buys'),
#  ('buys', 'german'),
#  ('german', 'biotech'),
#  ('biotech', 'production'),
#  ('production', 'site'),
#  ('site', 'novartis'),
#  ('novartis', 'increase'),
#  ('increase', 'vaccine'),
#  ('vaccine', 'output'),
#  ('output', 'astrazeneca'),
#  ('astrazeneca', 'nyseazn'),
#  ('nyseazn', 'ha'),
#  ('ha', 'entered'),
#  ('entered', 'agreement'),
#  ('agreement', 'dogma'),
#  ('dogma', 'therapeutics'),
#  ('therapeutics', 'acquire'),
#  ('acquire', 'preclinical'),
#  ('preclinical', 'oral'),
#  ('oral', 'pcsk'),
#  ('pcsk', 'inhibitor'),
#  ('inhibitor', 'programme'),
#  ('programme', 'company'),
#  ('company', 'aim'),
#  ('aim', 'take'),
#  ('take', 'programme'),
#  ('programme', 'forward'),
#  ('forward', 'clinical'),
#  ('clinical', 'development'),
#  ('development', 'dyslipidaemia'),
#  ('dyslipidaemia', 'abnormal'),
#  ('abnormal', 'amount'),
#  ('amount', 'lipid'),
#  ('lipid', 'blood'),
#  ('blood', 'familial'),
#  ('familial', 'hypercholesterolemia'),
#  ('hypercholesterolemia', 'common'),
#  ('common', 'genetic'),
#  ('genetic', 'condition'),
#  ('condition', 'cause'),
#  ('cause', 'high'),
#  ('high', 'cholesterol'),
#  ('cholesterol', 'pcsk'),
#  ('pcsk', 'protein'),
#  ('protein', 'regulates'),
#  ('regulates', 'level'),
#  ('level', 'lowdensity'),
#  ('lowdensity', 'lipoprotein'),
#  ('lipoprotein', 'ldl'),
#  ('ldl', 'bad'),
#  ('bad', 'cholesterol'),
#  ('cholesterol', 'blood'),
#  ('blood', 'increased'),
#  ('increased', 'activity'),
#  ('activity', 'pcsk'),
#  ('pcsk', 'associated'),
#  ('associated', 'high'),
#  ('high', 'ldl'),
#  ('ldl', 'cholesterol'),
#  ('cholesterol', 'acquired'),
#  ('acquired', 'pcsk'),
#  ('pcsk', 'inhibitor'),
#  ('inhibitor', 'small'),
#  ('small', 'molecule'),
#  ('molecule', 'bind'),
#  ('bind', 'directly'),
#  ('directly', 'novel'),
#  ('novel', 'part'),
#  ('part', 'pcsk'),
#  ('pcsk', 'shown'),
#  ('shown', 'block'),
#  ('block', 'activity'),
#  ('activity', 'lower'),
#  ('lower', 'ldl'),
#  ('ldl', 'cholesterol'),
#  ('cholesterol', 'preclinical'),
#  ('preclinical', 'model'),
#  ('model', 'currently'),
#  ('currently', 'oral'),
#  ('oral', 'pcsk'),
#  ('pcsk', 'inhibitor'),
#  ('inhibitor', 'available'),
#  ('available', 'patient'),
#  ('patient', 'clinical'),
#  ('clinical', 'development'),
#  ('development', 'mene'),
#  ('mene', 'pangalos'),
#  ('pangalos', 'executive'),
#  ('executive', 'vice'),
#  ('vice', 'president'),
#  ('president', 'biopharmaceuticals'),
#  ('biopharmaceuticals', 'rd'),
#  ('rd', 'said'),
#  ('said', 'raised'),
#  ('raised', 'ldl'),
#  ('ldl', 'cholesterol'),
#  ('cholesterol', 'key'),
#  ('key', 'risk'),
#  ('risk', 'factor'),
#  ('factor', 'cardiovascular'),
#  ('cardiovascular', 'disease'),
#  ('disease', 'estimated'),
#  ('estimated', 'cause'),
#  ('cause', 'million'),
#  ('million', 'death'),
#  ('death', 'worldwide'),
#  ('worldwide', 'every'),
#  ('every', 'year'),
#  ('year', 'whilst'),
#  ('whilst', 'pcsk'),
#  ('pcsk', 'well'),
#  ('well', 'validated'),
#  ('validated', 'target'),
#  ('target', 'lowering'),
#  ('lowering', 'ldl'),
#  ('ldl', 'cholesterol'),
#  ('cholesterol', 'ha'),
#  ('ha', 'hugely'),
#  ('hugely', 'challenging'),
#  ('challenging', 'target'),
#  ('target', 'inhibit'),
#  ('inhibit', 'small'),
#  ('small', 'molecule'),
#  ('molecule', 'agreement'),
#  ('agreement', 'dogma'),
#  ('dogma', 'therapeutics'),
#  ('therapeutics', 'offer'),
#  ('offer', 'u'),
#  ('u', 'opportunity'),
#  ('opportunity', 'develop'),
#  ('develop', 'first'),
#  ('first', 'small'),
#  ('small', 'molecule'),
#  ('molecule', 'orally'),
#  ('orally', 'bioavailable'),
#  ('bioavailable', 'pcsk'),
#  ('pcsk', 'inhibitor'),
#  ('inhibitor', 'patient'),
#  ('patient', 'risk'),
#  ('risk', 'cardiovascular'),
#  ('cardiovascular', 'disease'),
#  ('disease', 'brian'),
#  ('brian', 'hubbard'),
#  ('hubbard', 'chief'),
#  ('chief', 'executive'),
#  ('executive', 'officer'),
#  ('officer', 'dogma'),
#  ('dogma', 'therapeutics'),
#  ('therapeutics', 'said'),
#  ('said', 'built'),
#  ...]

# %%
news_word_count = Counter([word for value in news_df['word_tokens'].values for word in value.split()])
news_word_count
# Out:
# Counter({'astrazeneca': 1358,
#          'plcs': 74,
#          'nyseazn': 163,
#          'vaccine': 8754,
#          'didnt': 80,
#          'likely': 1229,
#          'cause': 286,
#          'adverse': 464,
#          'event': 628,
#          'suspended': 49,
#          'latestage': 252,
#          'human': 303,
#          'trial': 2732,
#          'drug': 1706,
#          'according': 702,
#          'oxford': 211,
#          'university': 201,
#          'happened': 237,
#          'volunteers': 20,
#          'british': 69,
#          'drugmakers': 60,
#          'chadox': 19,
#          'ncov': 19,
#          'developed': 342,
#          'unexplained': 33,
#          'neurological': 57,
#          'symptom': 201,
#          'including': 965,
#          'changed': 140,
#          'sensation': 20,
#          'weakness': 88,
#          'limb': 36,
#          'participant': 782,
#          'information': 551,
#          'document': 93,
#          'published': 181,
#          'codeveloping': 24,
#          'independent': 162,
#          'review': 636,
#          'illness': 101,
#          'either': 206,
#          'considered': 161,
#          'unlikely': 51,
#          'associated': 209,
#          'wa': 4472,
#          'insufficient': 36,
#          'evidence': 138,
#          'say': 240,
#          'certain': 193,
#          'related': 828,
#          'said': 3667,
#          'first': 1604,
#          'reported': 1692,
#          'reuters': 353,
#          'reviewer': 19,
#          'recommended': 140,
#          'vaccination': 545,
#          'continue': 462,
#          'reviewing': 48,
#          'case': 950,
#          'matters': 128,
#          'ha': 4012,
#          'resumed': 61,
#          'united': 469,
#          'kingdom': 98,
#          'india': 335,
#          'south': 307,
#          'africa': 149,
#          'brazil': 177,
#          'trials': 79,
#          'havent': 28,
#          'yet': 285,
#          'states': 303,
#          'food': 357,
#          'administration': 591,
#          'commissioner': 36,
#          'stephen': 37,
#          'hahn': 19,
#          'agency': 469,
#          'going': 359,
#          'significant': 423,
#          'work': 287,
#          'company': 6159,
#          'figure': 41,
#          'safety': 1213,
#          'issue': 201,
#          'moderna': 3112,
#          'inc': 11376,
#          'nysemrna': 22,
#          'pfizer': 2185,
#          'nysepfe': 607,
#          'frontrunners': 27,
#          'race': 86,
#          'covid': 5292,
#          'microsoft': 90,
#          'corporation': 815,
#          'nasdaqmsft': 60,
#          'cofounder': 55,
#          'bill': 122,
#          'gates': 63,
#          'claimed': 43,
#          'pfizers': 284,
#          'may': 1334,
#          'get': 366,
#          'emergency': 749,
#          'use': 1385,
#          'license': 269,
#          'end': 1033,
#          'october': 255,
#          'cnbc': 152,
#          'price': 3750,
#          'action': 383,
#          'share': 12488,
#          'closed': 788,
#          'almost': 127,
#          'lower': 721,
#          'wednesday': 1595,
#          'gained': 639,
#          'afterhours': 730,
#          'sessionastrazeneca': 21,
#          'events': 93,
#          'unrelated': 20,
#          'sinovac': 57,
#          'biotech': 1403,
#          'plan': 683,
#          'expand': 222,
#          'clinical': 1869,
#          'child': 240,
#          'adolescent': 189,
#          'later': 188,
#          'month': 1251,
#          'chinese': 139,
#          'maker': 151,
#          'hope': 106,
#          'carry': 38,
#          'study': 3328,
#          'healthy': 136,
#          'ranging': 31,
#          'age': 534,
#          'three': 562,
#          'filed': 193,
#          'national': 294,
#          'library': 19,
#          'medicine': 639,
#          'combined': 198,
#          'phase': 3199,
#          'take': 318,
#          'place': 138,
#          'chinas': 181,
#          'hebei': 16,
#          'province': 23,
#          'commence': 63,
#          'sept': 196,
#          'asfirst': 16,
#          'noticed': 25,
#          'drugmaker': 75,
#          'volunteer': 117,
#          'would': 586,
#          'given': 416,
#          'two': 890,
#          'dos': 1394,
#          'coronavac': 20,
#          'vaccineor': 16,
#          'alternatively': 17,
#          'placebo': 339,
#          'already': 233,
#          'approved': 791,
#          'regulator': 208,
#          'spokesperson': 35,
#          'told': 155,
#          'entire': 58,
#          'population': 285,
#          'important': 479,
#          'spread': 70,
#          'adult': 624,
#          'school': 73,
#          'kindergarten': 16,
#          'noted': 127,
#          'german': 234,
#          'partner': 393,
#          'biontech': 837,
#          'se': 281,
#          'nasdaqbntx': 279,
#          'seeking': 97,
#          'approval': 1054,
#          'young': 81,
#          'year': 2043,
#          'old': 94,
#          'nasdaqmrna': 625,
#          'distributed': 60,
#          'health': 1348,
#          'care': 418,
#          'worker': 81,
#          'highrisk': 94,
#          'group': 1215,
#          'late': 225,
#          'early': 623,
#          'november': 314,
#          'new': 7030,
#          'york': 206,
#          'times': 145,
#          'wasntthe': 16,
#          'halted': 50,
#          'due': 482,
#          'earliersinovac': 16,
#          'plans': 59,
#          'children': 58,
#          'adolescents': 48,
#          'stock': 8258,
#          'grab': 66,
#          'investor': 924,
#          'focus': 495,
#          'today': 1262,
#          'wall': 227,
#          'street': 270,
#          'expects': 422,
#          'apogee': 53,
#          'enterprises': 59,
#          'nasdaqapog': 37,
#          'report': 4700,
#          'quarterly': 3592,
#          'earnings': 4189,
#          'per': 4657,
#          'revenue': 4013,
#          'million': 5572,
#          'opening': 123,
#          'bell': 163,
#          'slipped': 140,
#          'trading': 3371,
#          'herman': 51,
#          'miller': 56,
#          'nasdaqmlhr': 34,
#          'strong': 323,
#          'rise': 162,
#          'fiscal': 143,
#          'quarter': 2182,
#          'sale': 821,
#          'also': 1856,
#          'exceeded': 71,
#          'analyst': 700,
#          'estimate': 419,
#          'jumped': 199,
#          'session': 2263,
#          'analysts': 233,
#          'expect': 199,
#          'cantel': 50,
#          'medical': 1012,
#          'corp': 884,
#          'nysecmd': 34,
#          'loss': 1236,
#          'find': 173,
#          'whats': 185,
#          'market': 2580,
#          'bring': 196,
#          'question': 169,
#          'benzingas': 168,
#          'premarket': 1726,
#          'prep': 79,
#          'choosing': 62,
#          'best': 199,
#          'broker': 138,
#          'part': 469,
#          'successful': 138,
#          'trader': 387,
#          'collaboration': 667,
#          'chiesi': 99,
#          'discover': 129,
#          'develop': 346,
#          'mrna': 2301,
#          'pulmonary': 149,
#          'arterial': 100,
#          'hypertension': 134,
#          'announced': 2103,
#          'vertex': 169,
#          'treat': 316,
#          'cystic': 113,
#          'fibrosis': 132,
#          'using': 404,
#          'gene': 378,
#          'editing': 91,
#          'chewy': 41,
#          'nysechwy': 20,
#          'public': 667,
#          'offering': 721,
#          'class': 140,
#          'common': 916,
#          'fell': 1224,
#          'tradingstocks': 38,
#          'watch': 155,
#          'september': 340,
#          'signing': 40,
#          'purchase': 252,
#          'agreement': 1014,
#          'novartis': 205,
#          'ag': 182,
#          'basel': 36,
#          'switzerland': 69,
#          'nysenvs': 67,
#          'acquire': 153,
#          'gmp': 71,
#          'certified': 48,
#          'manufacturing': 1047,
#          'facility': 428,
#          'marburg': 113,
#          'germany': 117,
#          'site': 486,
#          'biontechs': 155,
#          'production': 593,
#          'capacity': 264,
#          'fully': 173,
#          'operational': 99,
#          'transaction': 184,
#          'expected': 1847,
#          'close': 2084,
#          'fourth': 385,
#          'able': 159,
#          'produce': 194,
#          'bntb': 183,
#          'half': 251,
#          'thanks': 57,
#          'established': 141,
#          'team': 180,
#          'wellestablished': 33,
#          'substance': 83,
#          'product': 791,
#          'capability': 149,
#          'stateoftheart': 22,
#          'multiplatform': 17,
#          'currently': 421,
#          'employ': 25,
#          'approximately': 241,
#          'people': 718,
#          'equipped': 25,
#          'recombinant': 44,
#          'protein': 216,
#          'well': 694,
#          'cell': 811,
#          'therapy': 1048,
#          'hold': 310,
#          'culture': 25,
#          'lab': 100,
#          'viral': 97,
#          'vector': 45,
#          'potential': 870,
#          'longterm': 224,
#          'growth': 525,
#          'expansion': 336,
#          'significantly': 176,
#          'invested': 43,
#          'past': 281,
#          'five': 264,
#          'located': 46,
#          'life': 332,
#          'science': 197,
#          'industry': 336,
#          'park': 50,
#          'home': 174,
#          'employee': 90,
#          'total': 772,
#          'provides': 163,
#          'excellent': 33,
#          'infrastructure': 104,
#          'industrial': 244,
#          'within': 361,
#          'one': 1212,
#          'hour': 270,
#          'frankfurt': 22,
#          'airport': 30,
#          'minute': 63,
#          'headquarters': 27,
#          'mainz': 27,
#          'acquisition': 355,
#          'reflects': 46,
#          'commitment': 137,
#          'expanding': 66,
#          'order': 226,
#          'supply': 923,
#          'worldwide': 343,
#          'upon': 122,
#          'authorization': 759,
#          'working': 241,
#          'closely': 58,
#          'prepare': 40,
#          'smooth': 24,
#          'transition': 51,
#          'look': 375,
#          'forward': 245,
#          'welcoming': 19,
#          'member': 181,
#          'tapping': 18,
#          'impressive': 45,
#          'skill': 23,
#          'expertise': 68,
#          'strategic': 201,
#          'standpoint': 20,
#          'bolster': 30,
#          'vertically': 17,
#          'integrated': 59,
#          'business': 560,
#          'model': 108,
#          'inhouse': 26,
#          'formulation': 177,
#          'dr': 244,
#          'sierk': 18,
#          'poetting': 19,
#          'chief': 470,
#          'financial': 511,
#          'officer': 393,
#          'operating': 95,
#          'accelerate': 153,
#          'effort': 201,
#          'scaleup': 24,
#          'commercial': 465,
#          'candidate': 1548,
#          'bnt': 54,
#          'program': 689,
#          'includes': 125,
#          'testing': 225,
#          'europe': 360,
#          'america': 187,
#          'china': 366,
#          'evaluating': 440,
#          'lead': 321,
#          'global': 974,
#          'operate': 32,
#          'largest': 162,
#          'alongside': 46,
#          'existing': 116,
#          'addition': 243,
#          'least': 415,
#          'four': 257,
#          'start': 308,
#          'lnp': 52,
#          'pending': 90,
#          'regulatory': 771,
#          'manufacture': 157,
#          'additional': 785,
#          'therapeutic': 548,
#          'plant': 159,
#          'antibody': 780,
#          'support': 463,
#          'development': 1374,
#          'diversified': 47,
#          'cancer': 1860,
#          'infectious': 190,
#          'disease': 1806,
#          'pipeline': 297,
#          'intends': 156,
#          'contribute': 34,
#          'partnered': 46,
#          'fosun': 33,
#          'pharma': 617,
#          'subject': 236,
#          'long': 149,
#          'tradition': 16,
#          'innovation': 132,
#          'named': 78,
#          'behringwerke': 32,
#          'emil': 16,
#          'von': 25,
#          'behring': 18,
#          'antitoxin': 16,
#          'diphtheria': 16,
#          'tetanus': 16,
#          'used': 309,
#          'award': 40,
#          'money': 240,
#          'received': 868,
#          'nobel': 18,
#          'prize': 17,
#          'finance': 66,
#          'since': 297,
#          'founding': 22,
#          'forefront': 26,
#          'pharmaceutical': 426,
#          'biologic': 82,
#          'resulting': 73,
#          'highly': 204,
#          'anticipate': 48,
#          'completing': 31,
#          'satisfaction': 34,
#          'customary': 46,
#          'closing': 343,
#          'conditionbiontech': 16,
#          'buys': 26,
#          'increase': 468,
#          'output': 45,
#          'entered': 181,
#          'dogma': 96,
#          'therapeutics': 2945,
#          'preclinical': 196,
#          'oral': 333,
#          'pcsk': 197,
#          'inhibitor': 434,
#          'programme': 115,
#          'aim': 143,
#          'dyslipidaemia': 17,
#          'abnormal': 30,
#          'amount': 106,
#          'lipid': 88,
#          'blood': 408,
#          'familial': 28,
#          'hypercholesterolemia': 22,
#          'genetic': 148,
#          'condition': 232,
#          'high': 7130,
#          'cholesterol': 133,
#          'regulates': 16,
#          'level': 575,
#          'lowdensity': 19,
#          'lipoprotein': 23,
#          'ldl': 100,
#          'bad': 51,
#          'increased': 390,
#          'activity': 1028,
#          'acquired': 95,
#          'small': 226,
#          'molecule': 121,
#          'bind': 40,
#          'directly': 68,
#          'novel': 256,
#          'shown': 104,
#          'block': 51,
#          'available': 590,
#          'patient': 3049,
#          'mene': 44,
#          'pangalos': 47,
#          'executive': 441,
#          'vice': 192,
#          'president': 458,
#          'biopharmaceuticals': 99,
#          'rd': 425,
#          'raised': 189,
#          'key': 417,
#          'risk': 779,
#          'factor': 214,
#          'cardiovascular': 187,
#          'estimated': 1229,
#          'death': 483,
#          'every': 167,
#          'whilst': 17,
#          'validated': 41,
#          'target': 860,
#          'lowering': 29,
#          'hugely': 18,
#          'challenging': 29,
#          'inhibit': 24,
#          'offer': 302,
#          'u': 240,
#          'opportunity': 241,
#          'orally': 57,
#          'bioavailable': 17,
#          'brian': 34,
#          'hubbard': 16,
#          'built': 56,
#          'robust': 98,
#          'data': 2817,
#          'package': 60,
#          'highlight': 50,
#          'cholesterollowering': 17,
#          'meet': 224,
#          'goal': 163,
#          'access': 226,
#          'unable': 42,
#          'anticipates': 58,
#          'entering': 67,
#          'developmentastrazeneca': 16,
#          'acquires': 27,
#          'terms': 26,
#          'disclosed': 123,
#          'preopen': 84,
#          'mover': 99,
#          'us': 2548,
#          'future': 964,
#          'traded': 2594,
#          'trade': 1070,
#          'mostly': 127,
#          'previous': 413,
#          'federal': 261,
#          'reserve': 122,
#          'maintained': 89,
#          'current': 554,
#          'fed': 270,
#          'fund': 295,
#          'range': 254,
#          'zero': 30,
#          'investors': 378,
#          'awaiting': 84,
#          'initial': 412,
#          'jobless': 83,
#          'claim': 119,
#          'latest': 202,
#          'week': 7181,
#          'released': 266,
#          'et': 465,
#          'project': 63,
#          'declining': 109,
#          'housing': 45,
#          'building': 94,
#          'permit': 25,
#          'august': 248,
#          'philadelphia': 30,
#          'index': 1012,
#          'futures': 290,
#          'dow': 224,
#          'jones': 178,
#          'average': 377,
#          'dropped': 277,
#          'point': 530,
#          'standard': 314,
#          'poors': 90,
#          'nasdaq': 422,
#          'declined': 221,
#          'highest': 143,
#          'number': 550,
#          'world': 526,
#          'infection': 496,
#          'country': 590,
#          'exceeding': 91,
#          'around': 538,
#          'confirmed': 390,
#          'oil': 283,
#          'brent': 88,
#          'crude': 329,
#          'barrel': 240,
#          'wti': 95,
#          'inventory': 82,
#          'ended': 145,
#          'energy': 527,
#          'administrations': 49,
#          'weekly': 103,
#          'natural': 99,
#          'gas': 76,
#          'underground': 32,
#          'storage': 142,
#          'scheduled': 354,
#          'release': 465,
#          'peek': 87,
#          'markets': 264,
#          'european': 750,
#          'spanish': 113,
#          'ibex': 101,
#          'falling': 56,
#          'stoxx': 101,
#          'french': 128,
#          'cac': 101,
#          'dax': 100,
#          'londons': 98,
#          'ftse': 116,
#          'car': 84,
#          'registration': 67,
#          'union': 189,
#          'yearoveryear': 194,
#          'unit': 193,
#          'asian': 98,
#          'japans': 126,
#          'nikkei': 108,
#          'hong': 130,
#          'kongs': 103,
#          'hang': 94,
#          'seng': 95,
#          'shanghai': 102,
#          'composite': 153,
#          'indias': 123,
#          'bse': 83,
#          'sensex': 83,
#          'bank': 335,
#          'japan': 237,
#          'held': 135,
#          'shortterm': 41,
#          'interest': 365,
#          'rate': 592,
#          'recommendation': 187,
#          'jp': 79,
#          'morgan': 206,
#          'upgraded': 182,
#          'zoominfo': 41,
#          'technologies': 546,
#          'nasdaqzi': 20,
#          'neutral': 312,
#          'overweight': 198,
#          'breaking': 170,
#          'news': 541,
#          'planning': 82,
#          'agreed': 163,
#          'therapeuticspeek': 16,
#          'tumble': 17,
#          'ahead': 530,
#          'claims': 46,
#          'maintainedobjective': 16,
#          'response': 880,
#          'anddisease': 17,
#          'control': 299,
#          'complete': 234,
#          'xmt': 145,
#          'continues': 171,
#          'generally': 291,
#          'welltolerated': 69,
#          'signal': 147,
#          'presented': 223,
#          'discussed': 53,
#          'conference': 428,
#          'call': 1001,
#          'cambridge': 84,
#          'mass': 65,
#          'globe': 56,
#          'newswire': 71,
#          'mersana': 168,
#          'nasdaqmrsn': 55,
#          'clinicalstage': 131,
#          'biopharmaceutical': 133,
#          'focused': 184,
#          'discovering': 22,
#          'developing': 331,
#          'antibodydrug': 31,
#          'conjugate': 64,
#          'adcs': 38,
#          'targeting': 153,
#          'area': 217,
#          'unmet': 111,
#          'need': 482,
#          'updated': 222,
#          'interim': 607,
#          'tolerability': 176,
#          'efficacy': 840,
#          'ovarian': 318,
#          'cohort': 305,
#          'ongoing': 405,
#          'portion': 160,
#          'firstinclass': 64,
#          'adc': 155,
#          'napib': 97,
#          'society': 171,
#          'oncology': 612,
#          'esmo': 59,
#          'virtual': 247,
#          'congress': 114,
#          'host': 114,
#          'webcast': 149,
#          'etduring': 16,
#          'investigator': 90,
#          'erika': 16,
#          'hamilton': 25,
#          'md': 131,
#          'director': 145,
#          'breast': 271,
#          'gynecologic': 18,
#          'research': 630,
#          'sarah': 24,
#          'cannon': 20,
#          'institute': 191,
#          'tennessee': 24,
#          'present': 231,
#          'discus': 184,
#          'continued': 236,
#          'dolaflexin': 32,
#          'recently': 303,
#          'granted': 242,
#          'fda': 1696,
#          'fast': 123,
#          'track': 185,
#          'designation': 190,
#          'eager': 18,
#          'advance': 196,
#          'registrationenabling': 25,
#          'based': 564,
#          'observed': 334,
#          'antitumor': 51,
#          'favorable': 84,
#          'profile': 262,
#          'poor': 40,
#          'prognosis': 31,
#          'limited': 287,
#          'treatment': 2023,
#          'option': 1611,
#          'anna': 16,
#          'protopapas': 16,
#          'additionally': 115,
#          'presenting': 28,
#          'comprehensive': 50,
#          'mature': 28,
#          'result': 1690,
#          'analysis': 634,
#          'heavily': 45,
#          'pretreated': 28,
#          'platinumresistant': 38,
#          'refractory': 110,
#          'fallopian': 22,
#          'tube': 22,
#          'primary': 489,
#          'peritoneal': 21,
#          'line': 229,
#          'prior': 643,
#          'regardless': 45,
#          'platinum': 22,
#          'status': 65,
#          'cutoff': 40,
#          'include': 382,
#          'follow': 100,
#          'previously': 322,
#          'american': 349,
#          'asco': 46,
#          'finding': 189,
#          'consistent': 161,
#          'frequently': 38,
#          'treatmentrelated': 37,
#          'traes': 17,
#          'grade': 111,
#          'fatigue': 85,
#          'nausea': 60,
#          'decreased': 78,
#          'appetite': 31,
#          'vomiting': 31,
#          'transient': 29,
#          'ast': 17,
#          'elevation': 28,
#          'without': 320,
#          'change': 1995,
#          'bilirubin': 17,
#          'hys': 16,
#          'law': 74,
#          'severe': 463,
#          'neutropenia': 56,
#          'peripheral': 33,
#          'neuropathy': 21,
#          'ocular': 52,
#          'toxicity': 58,
#          'platinumrefractory': 16,
#          'treated': 283,
#          'bevacizumab': 92,
#          'parp': 66,
#          'evaluable': 34,
#          'achieved': 541,
#          'crs': 37,
#          'partial': 64,
#          'prs': 17,
#          'objective': 92,
#          'orr': 49,
#          'stable': 97,
#          'sd': 17,
#          'dcr': 20,
#          'cycle': 68,
#          'andof': 19,
#          'responses': 19,
#          'appeared': 64,
#          'deepen': 18,
#          'time': 1030,
#          'receiving': 184,
#          'reduced': 152,
#          'dose': 1143,
#          'majority': 102,
#          'responder': 39,
#          'reduction': 208,
#          'tumor': 342,
#          'volume': 408,
#          'achieving': 45,
#          'biomarkerbased': 16,
#          'selection': 57,
#          'strategy': 315,
#          'depth': 26,
#          'quality': 156,
#          'higher': 1194,
#          'expression': 81,
#          'onlyof': 16,
#          'median': 157,
#          'duration': 105,
#          'reached': 488,
#          'define': 25,
#          'set': 1679,
#          'details': 41,
#          'please': 97,
#          'dial': 19,
#          'domestic': 67,
#          'international': 389,
#          'provide': 355,
#          'id': 32,
#          'live': 137,
#          'presentation': 202,
#          'media': 74,
#          'section': 88,
#          'website': 128,
#          'atwwwmersanacom': 16,
#          'differentiated': 29,
#          'proprietary': 105,
#          'platform': 464,
#          'rapidly': 67,
#          'optimal': 43,
#          'meaningfully': 23,
#          'improve': 134,
#          'fighting': 32,
#          'mersanas': 64,
#          'proofofconcept': 70,
#          'nsclc': 120,
#          'adenocarcinoma': 44,
#          'second': 997,
#          'napibexpressing': 16,
#          'created': 78,
#          'customizable': 16,
#          'homogeneous': 16,
#          'dolasynthen': 16,
#          'escalation': 46,
#          'companys': 290,
#          'stage': 242,
#          'bh': 16,
#          'stingagonist': 16,
#          'immunosynthen': 16,
#          'multiple': 376,
#          'pipelinemersana': 16,
#          'announces': 360,
#          'plc': 673,
#          'positive': 866,
#          'cmv': 90,
#          'begin': 335,
#          'cove': 148,
#          'enrolled': 212,
#          'date': 763,
#          'protocol': 164,
#          'online': 131,
#          'enter': 142,
#          'seasonal': 190,
#          'flu': 236,
#          'effective': 501,
#          'twodose': 98,
#          'regimen': 190,
#          'chikungunya': 119,
#          'demonstrates': 31,
#          'ability': 186,
#          'safe': 199,
#          'repeat': 60,
#          'dosing': 198,
#          'next': 506,
#          'generation': 122,
#          'mma': 52,
#          'biotechnology': 244,
#          'pioneering': 95,
#          'messenger': 129,
#          'rna': 151,
#          'create': 154,
#          'transformative': 63,
#          'progress': 178,
#          'across': 437,
#          'portfolio': 259,
#          'asset': 427,
#          'annual': 314,
#          'day': 2485,
#          'made': 1232,
#          'last': 1928,
#          'ago': 138,
#          'matured': 16,
#          'actively': 55,
#          'preparing': 39,
#          'launch': 152,
#          'breadth': 24,
#          'modernas': 686,
#          'stphane': 98,
#          'bancel': 129,
#          'announcing': 35,
#          'increasing': 83,
#          'investment': 416,
#          'systemic': 174,
#          'secreted': 60,
#          'surface': 86,
#          'core': 104,
#          'modality': 82,
#          'sharing': 41,
#          'particularly': 78,
#          'rare': 309,
#          'field': 67,
#          'technology': 690,
#          'scale': 124,
#          'commercialization': 183,
#          'committed': 115,
#          'ever': 63,
#          'mission': 69,
#          'deliver': 260,
#          'promise': 85,
#          'prevent': 185,
#          'serious': 238,
#          'diseases': 86,
#          'conducted': 154,
#          'nih': 83,
#          'barda': 108,
#          'transparency': 31,
#          'context': 58,
#          'pandemic': 499,
#          'availableonline': 16,
#          'g': 193,
#          'completed': 153,
#          'investigational': 348,
#          'ind': 73,
#          'application': 729,
#          'pediatric': 255,
#          'rsv': 156,
#          'allowed': 74,
#          'proceed': 48,
#          'clinic': 118,
#          'dosed': 166,
#          'hmpvpiv': 32,
#          'oxlmrna': 16,
#          'monotherapy': 125,
#          ...})

# %%
import spacy
from spacy import displacy
nlp = spacy.load('en_core_web_sm')

# %%
news_doc = nlp(big_string[:10000])
displacy.render(news_doc, style='ent')
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">astrazeneca plcs nyseazn vaccine didnt likely cause adverse event suspended latestage human trial drug according
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     oxford university
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  happened volunteers
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     british
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  drugmakers chadox ncov vaccine trial developed unexplained neurological symptom including changed sensation weakness limb according participant information document published oxford codeveloping vaccine astrazeneca independent review illness either considered unlikely associated vaccine wa insufficient evidence say certain illness related vaccine
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     oxford
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  said
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     first
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORDINAL</span>
# </mark>
#  reported
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     reuters
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  independent reviewer recommended vaccination continue reviewing case according document matters astrazeneca ha resumed trial vaccine
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     united kingdom
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     india
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     south africa
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  brazil trials havent yet resumed
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     united states food drug administration
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  commissioner
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     stephen hahn
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  said agency going significant work company figure significant safety issue
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     moderna inc nysemrna pfizer inc nysepfe
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  likely frontrunners race covid vaccine
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     microsoft
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  corporation
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     nasdaqmsft
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  cofounder bill gates claimed pfizers vaccine may get emergency use license end
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     october
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  according
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     cnbc price
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  action astrazeneca share closed almost lower
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     wednesday
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  gained afterhours sessionastrazeneca trial participant adverse events likely unrelated covid vaccine oxford sinovac biotech ha plan expand clinical trial covid vaccine trial child adolescent
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     later month
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  happened
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     chinese
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  vaccine maker hope carry study healthy participant ranging
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     age three
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  according information company filed
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     national library medicine
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  combined phase phase trial take place chinas
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     hebei
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  province commence sept company said asfirst noticed
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; bo

# %%
[ent for ent in news_doc.ents]
# Out:
# [oxford university,
#  british,
#  oxford,
#  first,
#  reuters,
#  united kingdom,
#  india,
#  south africa,
#  united states food drug administration,
#  stephen hahn,
#  moderna inc nysemrna pfizer inc nysepfe,
#  microsoft,
#  nasdaqmsft,
#  october,
#  cnbc price,
#  wednesday,
#  later month,
#  chinese,
#  age three,
#  national library medicine,
#  hebei,
#  reuters,
#  two,
#  german,
#  united states food drug administration,
#  year old,
#  moderna inc nasdaqmrna,
#  late october early november,
#  new york times,
#  oxford university,
#  british,
#  united kingdom,
#  india,
#  south africa,
#  apogee enterprises inc nasdaqapog,
#  quarterly,
#  million,
#  bell apogee share,
#  herman miller inc nasdaqmlhr,
#  fiscal first quarter,
#  miller,
#  cantel medical corp nysecmd report,
#  quarterly,
#  million,
#  bell cantel,
#  moderna inc nasdaqmrna,
#  million,
#  september,
#  today,
#  ag,
#  switzerland,
#  marburg germany,
#  fourth quarter,
#  million,
#  first,
#  half,
#  past five year,
#  one hour,
#  frankfurt,
#  mainz germany,
#  bnt bnt,
#  five,
#  europe south america,
#  china,
#  one,
#  europe,
#  two,
#  four,
#  europe marburg,
#  first,
#  half,
#  china,
#  german,
#  million,
#  every year,
#  first,
#  fed,
#  zero,
#  apogee enterprises inc nasdaqapog,
#  medical corp nysecmd,
#  claim latest week,
#  september week,
#  august,
#  fed,
#  september,
#  nasdaq,
#  india,
#  brazil,
#  september,
#  weekly,
#  european,
#  today,
#  spanish,
#  europe,
#  french,
#  german,
#  european union,
#  august,
#  asian,
#  hang seng,
#  shanghai,
#  japan,
#  morgan,
#  zoominfo technologies inc nasdaqzi,
#  zoominfo,
#  wednesday,
#  moderna inc nasdaqmrna]

# %%
def clean_html(raw_html):
    cleanr = re.compile('\.+|<.*?>|&([a-z0-9]+|#[0-9]{1,6}|#x[0-9a-f]{1,6});')
    cleantext = re.sub(cleanr, '', raw_html).replace('\r', ' ').replace('\t', ' ').replace('\n', ' ').strip()
    return ' '.join(cleantext.split())

# %%
from nltk.sentiment.vader import SentimentIntensityAnalyzer
analyzer = SentimentIntensityAnalyzer()

news_features_df = pd.DataFrame()
news_features_df['date'] = news_df['date']
news_features_df['symbol'] = news_df['symbol']

news_features_df['compound_b'] = [analyzer.polarity_scores(v)['compound'] for v in news_df['body'].apply(clean_html)]
news_features_df['neg_b'] = [analyzer.polarity_scores(v)['neg'] for v in news_df['body'].apply(clean_html)]
news_features_df['neu_b'] = [analyzer.polarity_scores(v)['neu'] for v in news_df['body'].apply(clean_html)]
news_features_df['pos_b'] = [analyzer.polarity_scores(v)['pos'] for v in news_df['body'].apply(clean_html)]

news_features_df['compound_t'] = [analyzer.polarity_scores(v)['compound'] for v in news_df['title'].apply(clean_html)]
news_features_df['neg_t'] = [analyzer.polarity_scores(v)['neg'] for v in news_df['title'].apply(clean_html)]
news_features_df['neu_t'] = [analyzer.polarity_scores(v)['neu'] for v in news_df['title'].apply(clean_html)]
news_features_df['pos_t'] = [analyzer.polarity_scores(v)['pos'] for v in news_df['title'].apply(clean_html)]

# %%
news_features_df = news_features_df.groupby(['date', 'symbol']).sum()

# %%
news_features_df.to_csv('../Data/news_features.csv')
